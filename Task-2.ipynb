# %% [markdown]
# ### Task-2: Data Manipulation with Pandas.
#
# #### Description:
# This task involves using the Pandas library to manipulate data.
# #### Responsibility:
# Load a CSV file into a Pandas DataFrame. Perform operations like filtering data based on conditions, handling missing values and calculating summary statistics.

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\Manish Yadav\\Downloads\\Data.csv")  #Loading CSV File into a Pandas DataFrame

# %%
data  #Priting Loaded CSV File
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %% [markdown]
# ### Filtering Data Based on Conditions

# %%
data[data['Y-Kappa']>27]
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 1      31-01:00     27.6    16.810      79.022  1328.360      341.327
# 13     31-12:00     27.2    16.083      82.839  1332.331      366.855
# 40      1-15:00     27.1    13.558      83.117  1175.417      289.256
# 303    31-01:00     27.6    16.810      79.022  1328.360      341.327
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 1          351.050         329.067  1.549       537.201  ...        60.012
# 13         350.094         327.439  1.486       527.893  ...        60.271
# 40         339.168         318.386  1.360       480.184  ...        48.568
# 303        351.050         329.067  1.549       537.201  ...        60.012
#
#      Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# 1          330.823         304.879      163.202       665.975      1297.317
# 13         330.023         302.883      160.562       771.158      1299.974
# ...

# %%
data[data['ChipRate']>15]
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 305    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 306    31-04:00    22.90    15.618      93.244  1334.168      243.131
# 313    31-11:00    26.62    15.467      84.447  1334.255      386.971
# 317     4-16:00    17.80    16.625      78.367  1276.082      202.744
# 318     4-17:00    18.20    16.283      83.508  1288.104      234.284
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
data[(data['Y-Kappa']>20) & (data['ChipRate']>15)]
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 303    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 304    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 305    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 306    31-04:00    22.90    15.618      93.244  1334.168      243.131
# 313    31-11:00    26.62    15.467      84.447  1334.255      386.971
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %% [markdown]
# ### Handling Missing Values

# %%
data.drop_duplicates()
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 298    12-09:00    20.90    15.167      84.640  1283.706      339.440
# 299    12-10:00    24.98       NaN      85.034  1278.345      368.564
# 300    12-11:00    21.00       NaN      88.013  1307.722      278.842
# 301    12-12:00    21.40       NaN      85.490  1255.986      273.484
# 307    31-05:00    20.89    14.308      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
data.isnull().sum()
# Out:
# Observation          0
# Y-Kappa              0
# ChipRate             5
# BF-CMratio          17
# BlowFlow            16
# ChipLevel4           1
# T-upperExt-2         2
# T-lowerExt-2         2
# UCZAA               25
# WhiteFlow-4          1
# AAWhiteSt-4        151
# AA-Wood-4            1
# ChipMoisture-4       1
# SteamFlow-4          1
# Lower-HeatT-3        2
# Upper-HeatT-3        2
# ChipMass-4           1
# WeakLiquorF          1
# BlackFlow-2          2
# WeakWashF            1
# SteamHeatF-3         2
# T-Top-Chips-4        1
# SulphidityL-4      151
# dtype: int64

# %%
data.fillna(method='bfill',inplace=True)
# Out:
# C:\Users\Manish Yadav\AppData\Local\Temp\ipykernel_17332\1664202156.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='bfill',inplace=True)

# %%
data.isnull().sum()
# Out:
# Observation        0
# Y-Kappa            0
# ChipRate           0
# BF-CMratio         0
# BlowFlow           0
# ChipLevel4         0
# T-upperExt-2       0
# T-lowerExt-2       0
# UCZAA              0
# WhiteFlow-4        0
# AAWhiteSt-4        1
# AA-Wood-4          0
# ChipMoisture-4     0
# SteamFlow-4        0
# Lower-HeatT-3      0
# Upper-HeatT-3      0
# ChipMass-4         0
# WeakLiquorF        0
# BlackFlow-2        0
# WeakWashF          0
# SteamHeatF-3       0
# T-Top-Chips-4      0
# SulphidityL-4      1
# dtype: int64

# %%
data.columns = data.columns.str.strip()

data = data.drop(columns=['AAWhiteSt-4','SulphidityL-4'],axis=1)

# %%
data.columns
# Out:
# Index(['Observation', 'Y-Kappa', 'ChipRate', 'BF-CMratio', 'BlowFlow',
#        'ChipLevel4', 'T-upperExt-2', 'T-lowerExt-2', 'UCZAA', 'WhiteFlow-4',
#        'AA-Wood-4', 'ChipMoisture-4', 'SteamFlow-4', 'Lower-HeatT-3',
#        'Upper-HeatT-3', 'ChipMass-4', 'WeakLiquorF', 'BlackFlow-2',
#        'WeakWashF', 'SteamHeatF-3', 'T-Top-Chips-4'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Observation     324 non-null    object
#  1   Y-Kappa         324 non-null    float64
#  2   ChipRate        324 non-null    float64
#  3   BF-CMratio      324 non-null    float64
#  4   BlowFlow        324 non-null    float64
#  5   ChipLevel4      324 non-null    float64
#  6   T-upperExt-2    324 non-null    float64
#  7   T-lowerExt-2    324 non-null    float64
#  8   UCZAA           324 non-null    float64
#  9   WhiteFlow-4     324 non-null    float64
#  10  AA-Wood-4       324 non-null    float64
#  11  ChipMoisture-4  324 non-null    float64
#  12  SteamFlow-4     324 non-null    float64
#  13  Lower-HeatT-3   324 non-null    float64
#  14  Upper-HeatT-3   324 non-null    float64
#  15  ChipMass-4      324 non-null    float64
#  16  WeakLiquorF     324 non-null    float64
# ...

# %%
data = data.drop(columns = 'Observation',axis=1)

# %%
data.columns
# Out:
# Index(['Y-Kappa', 'ChipRate', 'BF-CMratio', 'BlowFlow', 'ChipLevel4',
#        'T-upperExt-2', 'T-lowerExt-2', 'UCZAA', 'WhiteFlow-4', 'AA-Wood-4',
#        'ChipMoisture-4', 'SteamFlow-4', 'Lower-HeatT-3', 'Upper-HeatT-3',
#        'ChipMass-4', 'WeakLiquorF', 'BlackFlow-2', 'WeakWashF', 'SteamHeatF-3',
#        'T-Top-Chips-4'],
#       dtype='object')

# %% [markdown]
# ### Calculating Summary Statistics

# %%
data.describe()
# Out:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4  \
# count  324.000000  324.000000  324.000000   324.000000  324.000000
# mean    20.635370   14.360432   87.550713  1225.260633  258.461815
# std      3.070036    1.505187    7.959156   154.192881   88.014016
# min     12.170000    9.983000   68.645000     0.000000    0.000000
# 25%     18.382500   13.333000   81.823500  1192.441750  213.527000
# 50%     20.845000   14.341500   86.999000  1259.479500  271.845500
# 75%     23.032500   15.544000   92.564000  1288.628750  322.537750
# max     27.600000   16.958000  121.717000  1351.240000  419.014000
#
#        T-upperExt-2  T-lowerExt-2       UCZAA  WhiteFlow-4   AA-Wood-4  \
# count    324.000000    324.000000  324.000000   324.000000  324.000000
# mean     356.939114    324.064747    1.491410   591.640583   17.833972
# std        9.191391      7.618850    0.104636    66.932875    0.912625
# min      339.168000    284.633000    1.182000   405.111000   16.471000
# ...
